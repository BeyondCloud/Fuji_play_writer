# %%
# 建立"情緒-動作"對應字典(多個相似情緒對應致同一動作)
#人類基本11種情緒:愉快、驚奇、悲傷、憤怒、厭惡、懼怕、興趣、輕蔑、痛苦、害羞、罪疚 (目前分類超過11種)

list_happy = ['高興', '樂了', '快樂', '高高興興', '快快樂樂', '高興的', '樂的', '快樂的', '高高興興的', '快快樂樂的', 
              '開心', '開心的','高興極了', '快快活活', '快快活活的', '快活', '快活的', '爽', '爽的', '歡樂的', '歡樂', 
              '幸福歡樂', '幸福歡樂的', '滿足的', '滿足', '滿意', '滿意的', '喜悅的', '愉悅', '愉悅的', '愉快', '愉快的'
             '心情很棒', '心情很好', '眉飛色舞', '眉開眼笑', '喜形於色', '樂以忘憂', 
              '和顏悅色', '心花怒放', '滿面春風', '自鳴得意', '高興萬分', '興高采烈', '不亦樂乎', '樂不可支'
             '歡天喜地', '喜出望外', '快活', '快活的']
list_surprise = ['驚覺', '驚訝', '驚喜的', '不驚覺的', '驚訝的', '驚喜', '瞠目結舌', '口呆目瞪', '驚喜交集', '驚詫不已'
                '詫異', '滿心驚詫', '驚詫', '驚詫的', '震驚']
list_sad = ['傷心', '難過', '低落', '失落', '失魂落魄', '悲傷', '傷心的', '難過的', '低落的', '失落的', 
            '失魂落魄的', '悲傷的', '失望', '失望的', '悲痛', '悲痛的', '哀痛的', '哀痛', '哀傷', '哀傷的'
            '悲勳', '悲勳的', '悲哀', '悲哀的', '沉痛', '沉痛的', '憂傷', '憂傷的', '心酸','心酸的', '憂愁', 
            '憂鬱', '憂鬱的', '難受', '難受的']
list_angry = ['生氣', '憤怒', '生氣的', '憤怒的', '失去理智', '失去理智的', '暴怒', '暴怒的', '不爽', '不爽的', '不高興'
             '不高興的', '不滿', '不滿的', '不滿意', '不滿意的', '不開心', '不開心的', '忿忿不平', '怒氣沖沖', '惱羞成怒' 
             '怒火中燒', '滿腔怒火', '憤懣難填', '雷霆大怒', '心情激憤', '怒不可竭', '怒不可遏', '怒髮衝冠', '怒氣衝天'
             '火冒三丈', '怒火中燒', '勃然大怒', '惱火']
list_hate = ['厭惡', '厭惡的', '不喜歡', '不喜歡的', '無聊', '無聊的', '感到排斥', '感到排斥的', '不以為然', '不以為然的']
list_fear = ['怕','害怕','嚇', '冒冷汗', '怕的','害怕的','嚇的', '提心吊膽', '驚魂未定', '驚慌失色', '心驚膽戰', '膽戰心驚']
list_interest = ['好奇', '興致勃勃', '感到有趣', '好奇的', '興致勃勃的', '感到有趣的', '躍躍欲試']
list_proud = ['得意', '驕傲', '輕蔑', '輕視', '得意的', '驕傲的', '輕蔑的', '耀武揚威的', '耀武揚威', 
             '神氣活現', '神氣活現的', '洋洋得意', '洋洋得意的', '自鳴得意', '頤指氣使', '心高氣傲']
list_painful = ['痛苦', '煎熬', '痛苦的', '煎熬的',  '痛不欲生', '心如刀刺', '心如刀割', '悲痛欲絕', '絕望', '絕望的']
list_shy = ['害羞', '害羞的','臉紅', '羞怯', '羞怯的', '膽小', '膽小的', '怯怯羞羞', '滿臉通紅']
list_sorry = ['對不起', '內疚','內疚的','抱歉', '過意不去', '抱歉的', '遺憾', '遺憾的', 
              '懊悔', '懊悔的', '後悔不已', '後悔', '後悔的', '不好意思', '不好意思的']
list_anxious = ['焦急', '著急', '著急的', '焦急的', '猶豫', '猶豫的', '猶豫不決', '猶豫不決的'
               '心慌意亂', '不安寧', '不安心', '擔心', '擔心的', '擔憂', '擔憂的', '憂慮', '憂慮的', '煩躁']
list_confident = ['不慌不忙', '自信的', '有信心', '安心', '不擔心', '不慌不忙的', '自信', '有信心的',
                  '安心的', '不擔心的', '輕鬆', '輕鬆的', '臨危不亂']
list_love = ['深情', '深情的', '含情脈脈', '含情脈脈的']
list_serious = ['認真', '認真的', '正經', '正經的', '一本正經', '一本正經的', '義正詞嚴', '義正詞嚴的', 
                '嚴肅', '嚴肅的', '謹慎', '謹慎的', '態度強硬', '態度強硬的', '一絲不苟']
list_tired = ['累', '累的', '疲倦', '疲倦的', '想睡', '想睡的','無精打采', '無精打采的', '虛弱', '虛弱的', '昏昏沉沉']
list_confused = ['疑惑', '疑惑的', '不解', '不解的', '困惑', '困惑的', '感到奇怪', '感到奇怪的']
list_excited = ['激動', '興奮', '雀躍', '雀躍的', '樂爆', '樂翻天', '雀躍三尺', '欣喜若狂']


ETA_dict = {list_happy:'手舞足蹈', list_surprise:'目瞪口呆', list_sad:'嘆氣', list_angry:'大罵', list_hate:'轉身搖頭',
            list_fear:'發抖', list_interest:'探頭觀望', list_proud:'雙手插腰大笑', list_painful:'抱頭痛哭', list_shy:'低頭',
            list_anxious:'來回踱步', list_confident:'拍胸脯點頭', list_love:'擁抱', list_serious:'雙手抱胸',
            list_tired:'打哈欠', list_confused:'歪頭和抓頭', list_excited:'又唱又跳'}
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# <ipython-input-2-81c571cc8c7b> in <module>()
#      42             list_fear:'發抖', list_interest:'探頭觀望', list_proud:'雙手插腰大笑', list_painful:'抱頭痛哭', list_shy:'低頭',
#      43             list_anxious:'來回踱步', list_confident:'拍胸脯點頭', list_love:'擁抱', list_serious:'雙手抱胸',
# ---> 44             list_tired:'打哈欠', list_confused:'歪頭和抓頭', list_excited:'又唱又跳'}
#
# TypeError: unhashable type: 'list'
